# %% [markdown]
# # Extraction of LOTUS / OSK secondary structures  <br><br>from JPred4 prediction
#
# - Author: Savandara BESSE & Leo Blondel
# - Creation: 07-07-2017
# - Last modification: 09-17-2019
#
# ______________________
#
# - Running JPred4 on LOTUS / OSK (X) sequences
#     - 1. Run `prepareInputs.csh` with `./INPUTS/FASTA/X_consensus_sequences.fasta` as parameter
#     - 2. Run `massSubmitScheduler.csh` with `X_consensus_sequences.fasta_dir` as parameter
#     - 3. Extract only .jnet files from `X_consensus_sequences.fasta_dir_output` folder and put them in a folder called `jpred4_raw_scores`
#
# ## Required inputs
# - MSA fasta file for LOTUS and OSK:
#     - __`./INPUTS/FASTA/LOTUS_consensus_alignment.fasta`__
#     - __`./INPUTS/FASTA/OSK_consensus_alignment.fasta`__
# - JSON file with oskar analysis results: __`./INPUTS/JSON_oskar_analysis.txt`__
# - JPRED scores folder for LOTUS : __`./INPUTS/2.6/LOTUS_raw_scores`__
# - JPRED scores folder for OSK : __`./INPUTS/2.6/OSK_raw_scores`__

# %%
LOTUS_alignement_file = '../Data/01_Oskar_identification/oskar_tracker_results/oskar_filtered.aligned.LOTUS_domain.fasta'
OSK_alignment_file = '../Data/01_Oskar_identification/oskar_tracker_results/oskar_filtered.aligned.OSK_domain.fasta'

# %% [markdown]
# # Generating jpred API results
# We need to split the sequences into jobs of 200 sequences max !

# %%
import jpredapi
from Bio import SeqIO
from Bio import Seq

# %%
email = 'lblondel@g.harvard.edu'

# %%
jpredapi.quota(email=email)
# Out:
# You've already submitted 88 today (out of 1000 jobs per user per day).
# <Response [200]>

# %%
# !mkdir tmp

# %%
# Reset the job csv file
f = open('../Data/02_Oskar_analyses/jpred_tmp/jobs.csv', 'w')
f.close()

# %%
def clean_seq(seq):
    tmp = ""
    for s in seq.seq:
        if s != '-':
            tmp += s
    seq.seq = Seq.Seq(tmp)
    return seq

def check_seq(seq):
    if len(seq) > 20 and len(seq) < 800:
        return True
    else:
        return False
    
def submit_seq(seq, domain):
    SeqIO.write(seq, './tmp/{}.fasta'.format(seq.name),'fasta')
    job = jpredapi.submit(
                            'single',
                            'fasta',
                            skipPDB=False,
                            file='./tmp/{}.fasta'.format(seq.name),
                            email=email,
                            name=domain
                            )
    jobid = job.text.split('cgi-bin/chklog?')[1].split('">')[0]
    return job, jobid, seq.name

def write_job_seq_table(jobs, domain):
    f = open('../Data/02_Oskar_analyses/jpred_tmp/jobs.csv', 'a')
    f.write('domain, job_id, seq_id')
    for job in jobs:
        f.write(','.join([domain, job[1], job[2]]))
    f.close()

# %%
# Doing LOTUS
handle = SeqIO.parse(LOTUS_alignement_file, 'fasta')
seqs = [s for s in handle]
seqs = [clean_seq(seq) for seq in seqs]
seqs = [seq for seq in seqs if check_seq(seq)]
jobs = [submit_seq(seq, 'LOTUS_V3') for seq in seqs]
write_job_seq_table(jobs, 'LOTUS')
# Out:
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCPR01060865.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_FWBmBGZ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_FWBmBGZ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGLV01050081.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_qr7ANZy">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_qr7ANZy</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFCQ01023354.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_2yQ_rSn">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_2yQ_rSn</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g73831.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_z8GLmyk">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_z8GLmyk</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDYE01076282.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fMS327P">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fMS327P</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDYK01051721.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8EtD_ja">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8EtD_ja</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDZZ01021815.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_WjF3w_7">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_WjF3w_7</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDCJ01039934.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Sy_glG8">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Sy_glG8</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBCX01024638.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_i6SSQvV">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_i6SSQvV</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDPI01010195.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_gyGL4sp">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_gyGL4sp</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDPL01008940.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tOTBMI1">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tOTBMI1</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBHN01008234.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9U42i7v">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9U42i7v</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_023025754.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_yL_LZJd">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_yL_LZJd</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GEUF01006592.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_aZ9gqsn">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_aZ9gqsn</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGMU01005923.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8sY1zcT">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8sY1zcT</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGMU01146895.1_5.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ts13qRC">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ts13qRC</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDNW01019662.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5hXG3qD">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5hXG3qD</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDLA01009331.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__12ypyR">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__12ypyR</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGKQ01129231.1_6.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_etfZKZR">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_etfZKZR</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GEZY01023300.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_vo7kiLr">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_vo7kiLr</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6403.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4pIV7Kz">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4pIV7Kz</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAPE01019095.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5KsN6GZ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5KsN6GZ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_019880291.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_QvUkF5W">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_QvUkF5W</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g1846.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_CAd3hrT">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_CAd3hrT</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFGA01008784.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_FK5vHp0">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_FK5vHp0</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g1587.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5ZPkKAH">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5ZPkKAH</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GATI02024491.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sQeq7j5">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sQeq7j5</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCFF01018410.1_6.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Iewjbb2">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Iewjbb2</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_023301197.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_a8v6KZh">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_a8v6KZh</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAKJ01009501.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_CcOLM0x">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_CcOLM0x</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAKJ01010751.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_G8SeqaI">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_G8SeqaI</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBRL01010261.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BnQZPSb">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BnQZPSb</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGAW01019355.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wvaev6B">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wvaev6B</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAWM01006639.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_87XQtOq">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_87XQtOq</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGAN01008121.1_6.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_lQEs0wg">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_lQEs0wg</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGAN01011936.1_6.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_RhnTPHb">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_RhnTPHb</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGBJ01017529.1_5.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_au7o7Xi">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_au7o7Xi</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGBK01015896.1_6.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_6t3aOmL">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_6t3aOmL</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GANO01003814.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__qea7Io">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__qea7Io</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFNI01017354.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_O76gnW3">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_O76gnW3</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAZD02016917.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BQ03peK">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BQ03peK</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGBM01030935.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_0ucMi9L">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_0ucMi9L</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBTE01009320.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_VYnyoAO">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_VYnyoAO</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_001848641.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ul_YFF6">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ul_YFF6</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g2916.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9JlmPSt">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9JlmPSt</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g3426.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_jrDjf_F">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_jrDjf_F</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g3491.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fegJSfG">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fegJSfG</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g303.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_u6WFuvU">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_u6WFuvU</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8324.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BoHkIGr">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BoHkIGr</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g5263.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_W7Qnypd">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_W7Qnypd</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8569.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tciHDjX">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tciHDjX</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6913.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4SGTkD9">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4SGTkD9</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8459.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_PGb1Tdy">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_PGb1Tdy</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g204.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4GNnltj">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4GNnltj</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8591.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_7Yn7J17">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_7Yn7J17</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g10533.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_l7defgv">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_l7defgv</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8282.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_H9YPRIN">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_H9YPRIN</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g2419.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wJ2rnK7">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wJ2rnK7</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g5007.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AgOMzzK">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AgOMzzK</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g2004.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MZ_cV9i">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MZ_cV9i</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g305.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_GSQ3PAQ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_GSQ3PAQ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGFL01000673.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_SAq84dv">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_SAq84dv</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_001656415.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9FJI5L9">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9FJI5L9</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFDL01015870.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_dXiSh0s">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_dXiSh0s</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_019540707.2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tsHzI7_">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tsHzI7_</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBEO01001325.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_66rfZ24">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_66rfZ24</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g10482.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sIKoroa">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sIKoroa</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_313289.3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_1e5UW0y">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_1e5UW0y</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GEMK01033802.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_A3kHUyc">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_A3kHUyc</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g4008.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AaaztmN">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AaaztmN</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCGO01032022.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_OiQ_z8m">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_OiQ_z8m</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GADM01000016.1_5.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_GfAPect">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_GfAPect</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_030572142.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_pZB7RTB">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_pZB7RTB</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_030374856.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4GSFhrr">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4GSFhrr</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_023173869.2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_1YC7UP8">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_1YC7UP8</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_001980894.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_f84ccLr">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_f84ccLr</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_022213619.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_1bSDTrP">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_1bSDTrP</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017856611.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_k93w_qZ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_k93w_qZ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017071884.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bkRkd1t">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bkRkd1t</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_016978919.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hT9Teal">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hT9Teal</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017104763.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_EaHyJOi">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_EaHyJOi</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017014240.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_jUXXdEX">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_jUXXdEX</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017031605.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_0glqPHS">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_0glqPHS</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017123986.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_IFKSJGS">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_IFKSJGS</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_016961451.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4WSM08H">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4WSM08H</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017058667.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MKF2vhy">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MKF2vhy</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017845653.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_akKibeB">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_akKibeB</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_002096875.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_a1eERhp">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_a1eERhp</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_002031969.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wWaa0ki">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wWaa0ki</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_001953297.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_saqdulX">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_saqdulX</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_001994345.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_f5rUW2j">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_f5rUW2j</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_002000116.2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tAWz6um">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tAWz6um</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_016941563.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_CwJMHme">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_CwJMHme</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_002070281.2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_VjQDsPl">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_VjQDsPl</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_002053269.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8tjOEkr">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8tjOEkr</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6282.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_RwTxeS8">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_RwTxeS8</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g9342.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_0WTkBRh">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_0WTkBRh</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g13566.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_DCJsqbe">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_DCJsqbe</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g14108.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9alETtF">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9alETtF</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g10514.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hX4Xno8">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hX4Xno8</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g9861.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ympZDwl">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ympZDwl</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6665.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fN7VIVy">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fN7VIVy</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g13723.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_dz6HICp">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_dz6HICp</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g4317.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_LMPUjXg">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_LMPUjXg</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g4469.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_l0ASIqi">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_l0ASIqi</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8280.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_vPY88bo">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_vPY88bo</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6827.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_NlSajHD">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_NlSajHD</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g10894.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tJffvit">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tJffvit</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g1452.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_GEgT9zR">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_GEgT9zR</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g2421.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bJN2GXi">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bJN2GXi</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g16848.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_acjlYtd">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_acjlYtd</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g7940.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_WkUftPv">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_WkUftPv</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6005.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ZiqN9NK">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ZiqN9NK</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g12827.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_rlljAkr">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_rlljAkr</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8764.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_EdKWVTt">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_EdKWVTt</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g1694.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9JIeU0M">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9JIeU0M</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g10104.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_nIxjXal">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_nIxjXal</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8692.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_nqN5tOg">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_nqN5tOg</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g510.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3IoakCs">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3IoakCs</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g757.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_uRfOulb">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_uRfOulb</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g989.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_nC2ArYA">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_nC2ArYA</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g1756.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_kYagceB">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_kYagceB</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g7457.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_TwG2bVS">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_TwG2bVS</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g2982.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bo1lq3y">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bo1lq3y</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g4964.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# ...
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBTG01033006.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_COOFtIv">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_COOFtIv</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCVC01025397.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_HszjeyI">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_HszjeyI</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_015178316.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_CQ8bBlB">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_CQ8bBlB</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBOH01019111.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fQwTnhT">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fQwTnhT</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFS01087549.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ZoaENRW">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ZoaENRW</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFS01087539.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_2qT2fww">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_2qT2fww</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAFR01040300.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_epqYLRp">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_epqYLRp</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBVH01018747.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hx5mV6O">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hx5mV6O</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GATC02018205.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_I31WqBI">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_I31WqBI</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GATC02016035.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_yHOAe4Q">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_yHOAe4Q</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GENS01144527.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bYOx4R3">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bYOx4R3</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GENI01153520.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_poh6CMe">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_poh6CMe</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAYK02016970.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_uRI4yly">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_uRI4yly</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAUH02014402.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__kpcSzj">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__kpcSzj</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGKZ01013502.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MlIGe8O">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MlIGe8O</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGFB01029731.1_5.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_JnHIfbv">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_JnHIfbv</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDVN01049780.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_R0dnqNx">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_R0dnqNx</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAWC01068728.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Q7DCa6F">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Q7DCa6F</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFVY01173144.1_5.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sa75lg_">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sa75lg_</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDBZ01020440.1_6.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Z0aJqcv">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Z0aJqcv</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDBZ01004059.1_5.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_H79i5ko">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_H79i5ko</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAUF02003364.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_dzNMiIt">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_dzNMiIt</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCWY01017914.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5MUrcPI">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5MUrcPI</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFK01042953.1_1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ziAFMma">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ziAFMma</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAYV02032680.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9h01kkN">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_9h01kkN</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAYV02023556.1_6.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_NVL53ox">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_NVL53ox</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFG01026980.1_5.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_lHO9NP0">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_lHO9NP0</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCZM01016483.1_6.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_IWlarbv">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_IWlarbv</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCXT01024844.1_6.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_LDi_UBq">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_LDi_UBq</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFM01026550.1_2.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Ot5cI0h">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Ot5cI0h</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCYQ01052767.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_xn9UoTS">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_xn9UoTS</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAXG02090017.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_DImovSV">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_DImovSV</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAXC02020747.1_5.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_kY3ZoEQ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_kY3ZoEQ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAYE02020013.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BzheE3F">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BzheE3F</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_026280917.1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MX6tao4">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MX6tao4</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g14948.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_GvirlLt">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_GvirlLt</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFQQ01016007.1_6.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_E5zqONV">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_E5zqONV</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAVM02025082.1_3.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_7nuTg14">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_7nuTg14</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GASS02003776.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_G03Hpop">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_G03Hpop</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g37762.t1.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5zcgY0x">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5zcgY0x</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAYJ02042457.1_4.fasta
# email: lblondel@g.harvard.edu
# name: LOTUS_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_OS0f_0u">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_OS0f_0u</a></li></ul> Accepted

# %%
done = []
to_check = jobs
while len(done) != len(jobs):
    for job in jobs:
        jobid = job[1]
        if jobid not in done:
            status = jpredapi.status(jobid=jobid)
            if 'finished' in status.text:
                jpredapi.get_results(jobid=jobid, results_dir_path='../Data/02_Oskar_analyses/jpred_tmp/', extract=True)
                done.append(jobid)
# Out:
# Your job status will be checked with the following parameters:
# Job id: jp_FWBmBGZ
# Get results: False
# Job jp_FWBmBGZ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_FWBmBGZ/jp_FWBmBGZ.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_FWBmBGZ
# Get results: True
# Job jp_FWBmBGZ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_FWBmBGZ/jp_FWBmBGZ.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_FWBmBGZ
# Your job status will be checked with the following parameters:
# Job id: jp_qr7ANZy
# Get results: False
# Job jp_qr7ANZy finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_qr7ANZy/jp_qr7ANZy.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_qr7ANZy
# Get results: True
# Job jp_qr7ANZy finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_qr7ANZy/jp_qr7ANZy.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_qr7ANZy
# Your job status will be checked with the following parameters:
# Job id: jp_2yQ_rSn
# Get results: False
# Job jp_2yQ_rSn finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_2yQ_rSn/jp_2yQ_rSn.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_2yQ_rSn
# Get results: True
# Job jp_2yQ_rSn finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_2yQ_rSn/jp_2yQ_rSn.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_2yQ_rSn
# Your job status will be checked with the following parameters:
# Job id: jp_z8GLmyk
# Get results: False
# Job jp_z8GLmyk finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_z8GLmyk/jp_z8GLmyk.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_z8GLmyk
# Get results: True
# Job jp_z8GLmyk finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_z8GLmyk/jp_z8GLmyk.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_z8GLmyk
# Your job status will be checked with the following parameters:
# Job id: jp_fMS327P
# Get results: False
# Job jp_fMS327P finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_fMS327P/jp_fMS327P.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_fMS327P
# Get results: True
# Job jp_fMS327P finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_fMS327P/jp_fMS327P.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_fMS327P
# Your job status will be checked with the following parameters:
# Job id: jp_8EtD_ja
# Get results: False
# Job jp_8EtD_ja finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_8EtD_ja/jp_8EtD_ja.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_8EtD_ja
# Get results: True
# Job jp_8EtD_ja finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_8EtD_ja/jp_8EtD_ja.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_8EtD_ja
# Your job status will be checked with the following parameters:
# Job id: jp_WjF3w_7
# Get results: False
# Job jp_WjF3w_7 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_WjF3w_7/jp_WjF3w_7.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_WjF3w_7
# Get results: True
# Job jp_WjF3w_7 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_WjF3w_7/jp_WjF3w_7.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_WjF3w_7
# Your job status will be checked with the following parameters:
# Job id: jp_Sy_glG8
# Get results: False
# Job jp_Sy_glG8 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_Sy_glG8/jp_Sy_glG8.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_Sy_glG8
# Get results: True
# Job jp_Sy_glG8 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_Sy_glG8/jp_Sy_glG8.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_Sy_glG8
# Your job status will be checked with the following parameters:
# Job id: jp_i6SSQvV
# Get results: False
# Job jp_i6SSQvV finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_i6SSQvV/jp_i6SSQvV.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_i6SSQvV
# Get results: True
# Job jp_i6SSQvV finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_i6SSQvV/jp_i6SSQvV.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_i6SSQvV
# Your job status will be checked with the following parameters:
# Job id: jp_gyGL4sp
# Get results: False
# Job jp_gyGL4sp finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_gyGL4sp/jp_gyGL4sp.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_gyGL4sp
# Get results: True
# Job jp_gyGL4sp finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_gyGL4sp/jp_gyGL4sp.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_gyGL4sp
# Your job status will be checked with the following parameters:
# Job id: jp_tOTBMI1
# Get results: False
# Job jp_tOTBMI1 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_tOTBMI1/jp_tOTBMI1.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_tOTBMI1
# Get results: True
# Job jp_tOTBMI1 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_tOTBMI1/jp_tOTBMI1.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_tOTBMI1
# Your job status will be checked with the following parameters:
# Job id: jp_9U42i7v
# Get results: False
# Job jp_9U42i7v finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_9U42i7v/jp_9U42i7v.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_9U42i7v
# Get results: True
# Job jp_9U42i7v finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_9U42i7v/jp_9U42i7v.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_9U42i7v
# Your job status will be checked with the following parameters:
# Job id: jp_yL_LZJd
# Get results: False
# Job jp_yL_LZJd finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_yL_LZJd/jp_yL_LZJd.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_yL_LZJd
# Get results: True
# Job jp_yL_LZJd finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_yL_LZJd/jp_yL_LZJd.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_yL_LZJd
# Your job status will be checked with the following parameters:
# Job id: jp_aZ9gqsn
# Get results: False
# Job jp_aZ9gqsn finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_aZ9gqsn/jp_aZ9gqsn.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_aZ9gqsn
# Get results: True
# Job jp_aZ9gqsn finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_aZ9gqsn/jp_aZ9gqsn.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_aZ9gqsn
# Your job status will be checked with the following parameters:
# Job id: jp_8sY1zcT
# Get results: False
# Job jp_8sY1zcT finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_8sY1zcT/jp_8sY1zcT.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_8sY1zcT
# Get results: True
# Job jp_8sY1zcT finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_8sY1zcT/jp_8sY1zcT.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_8sY1zcT
# Your job status will be checked with the following parameters:
# Job id: jp_ts13qRC
# Get results: False
# Job jp_ts13qRC finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_ts13qRC/jp_ts13qRC.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_ts13qRC
# Get results: True
# Job jp_ts13qRC finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_ts13qRC/jp_ts13qRC.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_ts13qRC
# Your job status will be checked with the following parameters:
# Job id: jp_5hXG3qD
# Get results: False
# Job jp_5hXG3qD finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_5hXG3qD/jp_5hXG3qD.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_5hXG3qD
# Get results: True
# Job jp_5hXG3qD finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_5hXG3qD/jp_5hXG3qD.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_5hXG3qD
# Your job status will be checked with the following parameters:
# Job id: jp__12ypyR
# Get results: False
# Job jp__12ypyR finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp__12ypyR/jp__12ypyR.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp__12ypyR
# Get results: True
# Job jp__12ypyR finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp__12ypyR/jp__12ypyR.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp__12ypyR
# Your job status will be checked with the following parameters:
# Job id: jp_etfZKZR
# Get results: False
# Job jp_etfZKZR finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_etfZKZR/jp_etfZKZR.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_etfZKZR
# Get results: True
# Job jp_etfZKZR finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_etfZKZR/jp_etfZKZR.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_etfZKZR
# Your job status will be checked with the following parameters:
# Job id: jp_vo7kiLr
# Get results: False
# Job jp_vo7kiLr finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_vo7kiLr/jp_vo7kiLr.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_vo7kiLr
# Get results: True
# Job jp_vo7kiLr finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_vo7kiLr/jp_vo7kiLr.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_vo7kiLr
# Your job status will be checked with the following parameters:
# Job id: jp_4pIV7Kz
# Get results: False
# Job jp_4pIV7Kz finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_4pIV7Kz/jp_4pIV7Kz.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_4pIV7Kz
# Get results: True
# Job jp_4pIV7Kz finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_4pIV7Kz/jp_4pIV7Kz.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_4pIV7Kz
# Your job status will be checked with the following parameters:
# Job id: jp_5KsN6GZ
# Get results: False
# Job jp_5KsN6GZ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_5KsN6GZ/jp_5KsN6GZ.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_5KsN6GZ
# Get results: True
# Job jp_5KsN6GZ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_5KsN6GZ/jp_5KsN6GZ.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_5KsN6GZ
# Your job status will be checked with the following parameters:
# Job id: jp_QvUkF5W
# Get results: False
# Job jp_QvUkF5W finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_QvUkF5W/jp_QvUkF5W.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_QvUkF5W
# Get results: True
# Job jp_QvUkF5W finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_QvUkF5W/jp_QvUkF5W.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_QvUkF5W
# Your job status will be checked with the following parameters:
# Job id: jp_CAd3hrT
# Get results: False
# Job jp_CAd3hrT finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_CAd3hrT/jp_CAd3hrT.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_CAd3hrT
# Get results: True
# Job jp_CAd3hrT finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_CAd3hrT/jp_CAd3hrT.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_CAd3hrT
# Your job status will be checked with the following parameters:
# Job id: jp_FK5vHp0
# Get results: False
# Job jp_FK5vHp0 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_FK5vHp0/jp_FK5vHp0.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_FK5vHp0
# Get results: True
# Job jp_FK5vHp0 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_FK5vHp0/jp_FK5vHp0.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_FK5vHp0
# Your job status will be checked with the following parameters:
# Job id: jp_5ZPkKAH
# Get results: False
# Job jp_5ZPkKAH finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_5ZPkKAH/jp_5ZPkKAH.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_5ZPkKAH
# Get results: True
# Job jp_5ZPkKAH finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_5ZPkKAH/jp_5ZPkKAH.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_5ZPkKAH
# Your job status will be checked with the following parameters:
# Job id: jp_sQeq7j5
# Get results: False
# Job jp_sQeq7j5 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_sQeq7j5/jp_sQeq7j5.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_sQeq7j5
# Get results: True
# Job jp_sQeq7j5 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_sQeq7j5/jp_sQeq7j5.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_sQeq7j5
# Your job status will be checked with the following parameters:
# Job id: jp_Iewjbb2
# Get results: False
# Job jp_Iewjbb2 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_Iewjbb2/jp_Iewjbb2.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_Iewjbb2
# Get results: True
# Job jp_Iewjbb2 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_Iewjbb2/jp_Iewjbb2.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_Iewjbb2
# Your job status will be checked with the following parameters:
# Job id: jp_a8v6KZh
# Get results: False
# Job jp_a8v6KZh finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_a8v6KZh/jp_a8v6KZh.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_a8v6KZh
# Get results: True
# Job jp_a8v6KZh finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_a8v6KZh/jp_a8v6KZh.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_a8v6KZh
# Your job status will be checked with the following parameters:
# Job id: jp_CcOLM0x
# Get results: False
# Job jp_CcOLM0x finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_CcOLM0x/jp_CcOLM0x.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_CcOLM0x
# Get results: True
# Job jp_CcOLM0x finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_CcOLM0x/jp_CcOLM0x.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_CcOLM0x
# Your job status will be checked with the following parameters:
# Job id: jp_G8SeqaI
# Get results: False
# Job jp_G8SeqaI finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_G8SeqaI/jp_G8SeqaI.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_G8SeqaI
# Get results: True
# Job jp_G8SeqaI finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_G8SeqaI/jp_G8SeqaI.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_G8SeqaI
# Your job status will be checked with the following parameters:
# Job id: jp_BnQZPSb
# Get results: False
# Job jp_BnQZPSb finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_BnQZPSb/jp_BnQZPSb.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_BnQZPSb
# Get results: True
# Job jp_BnQZPSb finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_BnQZPSb/jp_BnQZPSb.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_BnQZPSb
# Your job status will be checked with the following parameters:
# Job id: jp_wvaev6B
# Get results: False
# Job jp_wvaev6B finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_wvaev6B/jp_wvaev6B.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_wvaev6B
# Get results: True
# Job jp_wvaev6B finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_wvaev6B/jp_wvaev6B.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_wvaev6B
# Your job status will be checked with the following parameters:
# Job id: jp_87XQtOq
# Get results: False
# Job jp_87XQtOq finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_87XQtOq/jp_87XQtOq.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_87XQtOq
# Get results: True
# Job jp_87XQtOq finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_87XQtOq/jp_87XQtOq.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_87XQtOq
# Your job status will be checked with the following parameters:
# Job id: jp_lQEs0wg
# Get results: False
# Job jp_lQEs0wg finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_lQEs0wg/jp_lQEs0wg.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_lQEs0wg
# Get results: True
# Job jp_lQEs0wg finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_lQEs0wg/jp_lQEs0wg.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_lQEs0wg
# Your job status will be checked with the following parameters:
# Job id: jp_RhnTPHb
# Get results: False
# Job jp_RhnTPHb finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_RhnTPHb/jp_RhnTPHb.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_RhnTPHb
# Get results: True
# Job jp_RhnTPHb finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_RhnTPHb/jp_RhnTPHb.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_RhnTPHb
# Your job status will be checked with the following parameters:
# Job id: jp_au7o7Xi
# Get results: False
# Job jp_au7o7Xi finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_au7o7Xi/jp_au7o7Xi.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_au7o7Xi
# Get results: True
# Job jp_au7o7Xi finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_au7o7Xi/jp_au7o7Xi.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_au7o7Xi
# Your job status will be checked with the following parameters:
# Job id: jp_6t3aOmL
# Get results: False
# Job jp_6t3aOmL finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_6t3aOmL/jp_6t3aOmL.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_6t3aOmL
# Get results: True
# Job jp_6t3aOmL finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_6t3aOmL/jp_6t3aOmL.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_6t3aOmL
# Your job status will be checked with the following parameters:
# Job id: jp__qea7Io
# Get results: False
# Job jp__qea7Io finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp__qea7Io/jp__qea7Io.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp__qea7Io
# Get results: True
# Job jp__qea7Io finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp__qea7Io/jp__qea7Io.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp__qea7Io
# Your job status will be checked with the following parameters:
# Job id: jp_O76gnW3
# Get results: False
# Job jp_O76gnW3 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_O76gnW3/jp_O76gnW3.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_O76gnW3
# Get results: True
# Job jp_O76gnW3 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_O76gnW3/jp_O76gnW3.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_O76gnW3
# Your job status will be checked with the following parameters:
# Job id: jp_BQ03peK
# Get results: False
# Job jp_BQ03peK finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_BQ03peK/jp_BQ03peK.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_BQ03peK
# Get results: True
# Job jp_BQ03peK finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_BQ03peK/jp_BQ03peK.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_BQ03peK
# Your job status will be checked with the following parameters:
# Job id: jp_0ucMi9L
# Get results: False
# Job jp_0ucMi9L finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_0ucMi9L/jp_0ucMi9L.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_0ucMi9L
# Get results: True
# Job jp_0ucMi9L finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_0ucMi9L/jp_0ucMi9L.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_0ucMi9L
# Your job status will be checked with the following parameters:
# Job id: jp_VYnyoAO
# Get results: False
# Job jp_VYnyoAO finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_VYnyoAO/jp_VYnyoAO.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_VYnyoAO
# Get results: True
# Job jp_VYnyoAO finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_VYnyoAO/jp_VYnyoAO.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_VYnyoAO
# Your job status will be checked with the following parameters:
# Job id: jp_ul_YFF6
# Get results: False
# Job jp_ul_YFF6 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_ul_YFF6/jp_ul_YFF6.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_ul_YFF6
# Get results: True
# Job jp_ul_YFF6 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_ul_YFF6/jp_ul_YFF6.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_ul_YFF6
# Your job status will be checked with the following parameters:
# Job id: jp_9JlmPSt
# Get results: False
# Job jp_9JlmPSt finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_9JlmPSt/jp_9JlmPSt.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_9JlmPSt
# Get results: True
# Job jp_9JlmPSt finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_9JlmPSt/jp_9JlmPSt.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_9JlmPSt
# Your job status will be checked with the following parameters:
# Job id: jp_jrDjf_F
# Get results: False
# Job jp_jrDjf_F finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_jrDjf_F/jp_jrDjf_F.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_jrDjf_F
# Get results: True
# Job jp_jrDjf_F finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_jrDjf_F/jp_jrDjf_F.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_jrDjf_F
# Your job status will be checked with the following parameters:
# Job id: jp_fegJSfG
# Get results: False
# Job jp_fegJSfG finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_fegJSfG/jp_fegJSfG.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_fegJSfG
# Get results: True
# Job jp_fegJSfG finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_fegJSfG/jp_fegJSfG.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_fegJSfG
# Your job status will be checked with the following parameters:
# Job id: jp_u6WFuvU
# Get results: False
# Job jp_u6WFuvU finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_u6WFuvU/jp_u6WFuvU.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_u6WFuvU
# Get results: True
# Job jp_u6WFuvU finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_u6WFuvU/jp_u6WFuvU.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_u6WFuvU
# Your job status will be checked with the following parameters:
# Job id: jp_BoHkIGr
# Get results: False
# Job jp_BoHkIGr finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_BoHkIGr/jp_BoHkIGr.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_BoHkIGr
# Get results: True
# Job jp_BoHkIGr finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_BoHkIGr/jp_BoHkIGr.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_BoHkIGr
# Your job status will be checked with the following parameters:
# Job id: jp_W7Qnypd
# Get results: False
# Job jp_W7Qnypd finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_W7Qnypd/jp_W7Qnypd.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_W7Qnypd
# Get results: True
# Job jp_W7Qnypd finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_W7Qnypd/jp_W7Qnypd.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_W7Qnypd
# Your job status will be checked with the following parameters:
# Job id: jp_tciHDjX
# Get results: False
# Job jp_tciHDjX finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_tciHDjX/jp_tciHDjX.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_tciHDjX
# Get results: True
# Job jp_tciHDjX finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_tciHDjX/jp_tciHDjX.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_tciHDjX
# Your job status will be checked with the following parameters:
# Job id: jp_4SGTkD9
# Get results: False
# Job jp_4SGTkD9 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_4SGTkD9/jp_4SGTkD9.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_4SGTkD9
# Get results: True
# Job jp_4SGTkD9 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_4SGTkD9/jp_4SGTkD9.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_4SGTkD9
# Your job status will be checked with the following parameters:
# Job id: jp_PGb1Tdy
# Get results: False
# Job jp_PGb1Tdy finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_PGb1Tdy/jp_PGb1Tdy.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_PGb1Tdy
# Get results: True
# Job jp_PGb1Tdy finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_PGb1Tdy/jp_PGb1Tdy.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_PGb1Tdy
# Your job status will be checked with the following parameters:
# Job id: jp_4GNnltj
# Get results: False
# Job jp_4GNnltj finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_4GNnltj/jp_4GNnltj.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_4GNnltj
# Get results: True
# Job jp_4GNnltj finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_4GNnltj/jp_4GNnltj.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_4GNnltj
# Your job status will be checked with the following parameters:
# Job id: jp_7Yn7J17
# Get results: False
# Job jp_7Yn7J17 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_7Yn7J17/jp_7Yn7J17.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_7Yn7J17
# Get results: True
# Job jp_7Yn7J17 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_7Yn7J17/jp_7Yn7J17.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_7Yn7J17
# Your job status will be checked with the following parameters:
# Job id: jp_l7defgv
# Get results: False
# Job jp_l7defgv finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_l7defgv/jp_l7defgv.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_l7defgv
# Get results: True
# Job jp_l7defgv finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_l7defgv/jp_l7defgv.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_l7defgv
# Your job status will be checked with the following parameters:
# Job id: jp_H9YPRIN
# Get results: False
# Job jp_H9YPRIN finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_H9YPRIN/jp_H9YPRIN.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_H9YPRIN
# Get results: True
# Job jp_H9YPRIN finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_H9YPRIN/jp_H9YPRIN.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_H9YPRIN
# Your job status will be checked with the following parameters:
# Job id: jp_wJ2rnK7
# Get results: False
# Job jp_wJ2rnK7 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_wJ2rnK7/jp_wJ2rnK7.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_wJ2rnK7
# Get results: True
# Job jp_wJ2rnK7 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_wJ2rnK7/jp_wJ2rnK7.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_wJ2rnK7
# Your job status will be checked with the following parameters:
# Job id: jp_AgOMzzK
# Get results: False
# Job jp_AgOMzzK finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_AgOMzzK/jp_AgOMzzK.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_AgOMzzK
# Get results: True
# Job jp_AgOMzzK finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_AgOMzzK/jp_AgOMzzK.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_AgOMzzK
# Your job status will be checked with the following parameters:
# Job id: jp_MZ_cV9i
# Get results: False
# Job jp_MZ_cV9i finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_MZ_cV9i/jp_MZ_cV9i.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_MZ_cV9i
# Get results: True
# Job jp_MZ_cV9i finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_MZ_cV9i/jp_MZ_cV9i.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_MZ_cV9i
# Your job status will be checked with the following parameters:
# Job id: jp_GSQ3PAQ
# Get results: False
# Job jp_GSQ3PAQ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_GSQ3PAQ/jp_GSQ3PAQ.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_GSQ3PAQ
# Get results: True
# Job jp_GSQ3PAQ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_GSQ3PAQ/jp_GSQ3PAQ.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_GSQ3PAQ
# Your job status will be checked with the following parameters:
# Job id: jp_SAq84dv
# Get results: False
# Job jp_SAq84dv finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_SAq84dv/jp_SAq84dv.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_SAq84dv
# Get results: True
# Job jp_SAq84dv finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_SAq84dv/jp_SAq84dv.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_SAq84dv
# Your job status will be checked with the following parameters:
# Job id: jp_9FJI5L9
# Get results: False
# Job jp_9FJI5L9 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_9FJI5L9/jp_9FJI5L9.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_9FJI5L9
# Get results: True
# Job jp_9FJI5L9 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_9FJI5L9/jp_9FJI5L9.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_9FJI5L9
# Your job status will be checked with the following parameters:
# Job id: jp_dXiSh0s
# Get results: False
# Job jp_dXiSh0s finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_dXiSh0s/jp_dXiSh0s.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_dXiSh0s
# Get results: True
# Job jp_dXiSh0s finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_dXiSh0s/jp_dXiSh0s.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_dXiSh0s
# Your job status will be checked with the following parameters:
# Job id: jp_tsHzI7_
# Get results: False
# Job jp_tsHzI7_ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_tsHzI7_/jp_tsHzI7_.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_tsHzI7_
# Get results: True
# Job jp_tsHzI7_ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_tsHzI7_/jp_tsHzI7_.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_tsHzI7_
# Your job status will be checked with the following parameters:
# Job id: jp_66rfZ24
# Get results: False
# Job jp_66rfZ24 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_66rfZ24/jp_66rfZ24.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_66rfZ24
# Get results: True
# Job jp_66rfZ24 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_66rfZ24/jp_66rfZ24.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_66rfZ24
# Your job status will be checked with the following parameters:
# Job id: jp_sIKoroa
# Get results: False
# Job jp_sIKoroa finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_sIKoroa/jp_sIKoroa.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_sIKoroa
# Get results: True
# Job jp_sIKoroa finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_sIKoroa/jp_sIKoroa.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_sIKoroa
# Your job status will be checked with the following parameters:
# Job id: jp_1e5UW0y
# Get results: False
# Job jp_1e5UW0y finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_1e5UW0y/jp_1e5UW0y.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_1e5UW0y
# Get results: True
# Job jp_1e5UW0y finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_1e5UW0y/jp_1e5UW0y.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_1e5UW0y
# Your job status will be checked with the following parameters:
# Job id: jp_A3kHUyc
# Get results: False
# Job jp_A3kHUyc finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_A3kHUyc/jp_A3kHUyc.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_A3kHUyc
# Get results: True
# Job jp_A3kHUyc finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_A3kHUyc/jp_A3kHUyc.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_A3kHUyc
# Your job status will be checked with the following parameters:
# Job id: jp_AaaztmN
# Get results: False
# Job jp_AaaztmN finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_AaaztmN/jp_AaaztmN.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_AaaztmN
# Get results: True
# Job jp_AaaztmN finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_AaaztmN/jp_AaaztmN.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_AaaztmN
# Your job status will be checked with the following parameters:
# Job id: jp_OiQ_z8m
# Get results: False
# Job jp_OiQ_z8m finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_OiQ_z8m/jp_OiQ_z8m.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_OiQ_z8m
# Get results: True
# Job jp_OiQ_z8m finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_OiQ_z8m/jp_OiQ_z8m.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_OiQ_z8m
# Your job status will be checked with the following parameters:
# Job id: jp_GfAPect
# Get results: False
# Job jp_GfAPect finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_GfAPect/jp_GfAPect.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_GfAPect
# Get results: True
# Job jp_GfAPect finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_GfAPect/jp_GfAPect.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_GfAPect
# Your job status will be checked with the following parameters:
# Job id: jp_pZB7RTB
# Get results: False
# Job jp_pZB7RTB finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_pZB7RTB/jp_pZB7RTB.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_pZB7RTB
# Get results: True
# Job jp_pZB7RTB finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_pZB7RTB/jp_pZB7RTB.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_pZB7RTB
# Your job status will be checked with the following parameters:
# Job id: jp_4GSFhrr
# Get results: False
# Job jp_4GSFhrr finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_4GSFhrr/jp_4GSFhrr.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_4GSFhrr
# Get results: True
# Job jp_4GSFhrr finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_4GSFhrr/jp_4GSFhrr.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_4GSFhrr
# Your job status will be checked with the following parameters:
# Job id: jp_1YC7UP8
# Get results: False
# Job jp_1YC7UP8 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_1YC7UP8/jp_1YC7UP8.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_1YC7UP8
# Get results: True
# Job jp_1YC7UP8 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_1YC7UP8/jp_1YC7UP8.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_1YC7UP8
# Your job status will be checked with the following parameters:
# Job id: jp_f84ccLr
# Get results: False
# Job jp_f84ccLr finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_f84ccLr/jp_f84ccLr.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_f84ccLr
# Get results: True
# Job jp_f84ccLr finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_f84ccLr/jp_f84ccLr.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_f84ccLr
# Your job status will be checked with the following parameters:
# Job id: jp_1bSDTrP
# Get results: False
# Job jp_1bSDTrP finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_1bSDTrP/jp_1bSDTrP.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_1bSDTrP
# Get results: True
# Job jp_1bSDTrP finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_1bSDTrP/jp_1bSDTrP.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_1bSDTrP
# Your job status will be checked with the following parameters:
# Job id: jp_k93w_qZ
# Get results: False
# Job jp_k93w_qZ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_k93w_qZ/jp_k93w_qZ.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_k93w_qZ
# Get results: True
# Job jp_k93w_qZ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_k93w_qZ/jp_k93w_qZ.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_k93w_qZ
# Your job status will be checked with the following parameters:
# Job id: jp_bkRkd1t
# Get results: False
# Job jp_bkRkd1t finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_bkRkd1t/jp_bkRkd1t.results.html
#
#
# ...
# Your job status will be checked with the following parameters:
# Job id: jp_JnHIfbv
# Get results: False
# Job jp_JnHIfbv finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_JnHIfbv/jp_JnHIfbv.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_JnHIfbv
# Get results: True
# Job jp_JnHIfbv finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_JnHIfbv/jp_JnHIfbv.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_JnHIfbv
# Your job status will be checked with the following parameters:
# Job id: jp_R0dnqNx
# Get results: False
# Job jp_R0dnqNx finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_R0dnqNx/jp_R0dnqNx.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_R0dnqNx
# Get results: True
# Job jp_R0dnqNx finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_R0dnqNx/jp_R0dnqNx.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_R0dnqNx
# Your job status will be checked with the following parameters:
# Job id: jp_Q7DCa6F
# Get results: False
# Job jp_Q7DCa6F finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_Q7DCa6F/jp_Q7DCa6F.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_Q7DCa6F
# Get results: True
# Job jp_Q7DCa6F finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_Q7DCa6F/jp_Q7DCa6F.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_Q7DCa6F
# Your job status will be checked with the following parameters:
# Job id: jp_sa75lg_
# Get results: False
# Job jp_sa75lg_ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_sa75lg_/jp_sa75lg_.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_sa75lg_
# Get results: True
# Job jp_sa75lg_ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_sa75lg_/jp_sa75lg_.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_sa75lg_
# Your job status will be checked with the following parameters:
# Job id: jp_Z0aJqcv
# Get results: False
# Job jp_Z0aJqcv finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_Z0aJqcv/jp_Z0aJqcv.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_Z0aJqcv
# Get results: True
# Job jp_Z0aJqcv finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_Z0aJqcv/jp_Z0aJqcv.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_Z0aJqcv
# Your job status will be checked with the following parameters:
# Job id: jp_H79i5ko
# Get results: False
# Job jp_H79i5ko finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_H79i5ko/jp_H79i5ko.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_H79i5ko
# Get results: True
# Job jp_H79i5ko finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_H79i5ko/jp_H79i5ko.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_H79i5ko
# Your job status will be checked with the following parameters:
# Job id: jp_dzNMiIt
# Get results: False
# Job jp_dzNMiIt finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_dzNMiIt/jp_dzNMiIt.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_dzNMiIt
# Get results: True
# Job jp_dzNMiIt finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_dzNMiIt/jp_dzNMiIt.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_dzNMiIt
# Your job status will be checked with the following parameters:
# Job id: jp_5MUrcPI
# Get results: False
# Job jp_5MUrcPI finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_5MUrcPI/jp_5MUrcPI.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_5MUrcPI
# Get results: True
# Job jp_5MUrcPI finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_5MUrcPI/jp_5MUrcPI.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_5MUrcPI
# Your job status will be checked with the following parameters:
# Job id: jp_ziAFMma
# Get results: False
# Job jp_ziAFMma finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_ziAFMma/jp_ziAFMma.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_ziAFMma
# Get results: True
# Job jp_ziAFMma finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_ziAFMma/jp_ziAFMma.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_ziAFMma
# Your job status will be checked with the following parameters:
# Job id: jp_9h01kkN
# Get results: False
# Job jp_9h01kkN finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_9h01kkN/jp_9h01kkN.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_9h01kkN
# Get results: True
# Job jp_9h01kkN finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_9h01kkN/jp_9h01kkN.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_9h01kkN
# Your job status will be checked with the following parameters:
# Job id: jp_NVL53ox
# Get results: False
# Job jp_NVL53ox finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_NVL53ox/jp_NVL53ox.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_NVL53ox
# Get results: True
# Job jp_NVL53ox finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_NVL53ox/jp_NVL53ox.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_NVL53ox
# Your job status will be checked with the following parameters:
# Job id: jp_lHO9NP0
# Get results: False
# Job jp_lHO9NP0 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_lHO9NP0/jp_lHO9NP0.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_lHO9NP0
# Get results: True
# Job jp_lHO9NP0 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_lHO9NP0/jp_lHO9NP0.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_lHO9NP0
# Your job status will be checked with the following parameters:
# Job id: jp_IWlarbv
# Get results: False
# Job jp_IWlarbv finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_IWlarbv/jp_IWlarbv.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_IWlarbv
# Get results: True
# Job jp_IWlarbv finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_IWlarbv/jp_IWlarbv.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_IWlarbv
# Your job status will be checked with the following parameters:
# Job id: jp_LDi_UBq
# Get results: False
# Job jp_LDi_UBq finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_LDi_UBq/jp_LDi_UBq.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_LDi_UBq
# Get results: True
# Job jp_LDi_UBq finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_LDi_UBq/jp_LDi_UBq.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_LDi_UBq
# Your job status will be checked with the following parameters:
# Job id: jp_Ot5cI0h
# Get results: False
# Job jp_Ot5cI0h finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_Ot5cI0h/jp_Ot5cI0h.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_Ot5cI0h
# Get results: True
# Job jp_Ot5cI0h finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_Ot5cI0h/jp_Ot5cI0h.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_Ot5cI0h
# Your job status will be checked with the following parameters:
# Job id: jp_xn9UoTS
# Get results: False
# Job jp_xn9UoTS finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_xn9UoTS/jp_xn9UoTS.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_xn9UoTS
# Get results: True
# Job jp_xn9UoTS finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_xn9UoTS/jp_xn9UoTS.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_xn9UoTS
# Your job status will be checked with the following parameters:
# Job id: jp_DImovSV
# Get results: False
# Job jp_DImovSV finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_DImovSV/jp_DImovSV.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_DImovSV
# Get results: True
# Job jp_DImovSV finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_DImovSV/jp_DImovSV.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_DImovSV
# Your job status will be checked with the following parameters:
# Job id: jp_kY3ZoEQ
# Get results: False
# Job jp_kY3ZoEQ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_kY3ZoEQ/jp_kY3ZoEQ.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_kY3ZoEQ
# Get results: True
# Job jp_kY3ZoEQ finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_kY3ZoEQ/jp_kY3ZoEQ.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_kY3ZoEQ
# Your job status will be checked with the following parameters:
# Job id: jp_BzheE3F
# Get results: False
# Job jp_BzheE3F finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_BzheE3F/jp_BzheE3F.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_BzheE3F
# Get results: True
# Job jp_BzheE3F finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_BzheE3F/jp_BzheE3F.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_BzheE3F
# Your job status will be checked with the following parameters:
# Job id: jp_MX6tao4
# Get results: False
# Job jp_MX6tao4 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_MX6tao4/jp_MX6tao4.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_MX6tao4
# Get results: True
# Job jp_MX6tao4 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_MX6tao4/jp_MX6tao4.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_MX6tao4
# Your job status will be checked with the following parameters:
# Job id: jp_GvirlLt
# Get results: False
# Job jp_GvirlLt finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_GvirlLt/jp_GvirlLt.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_GvirlLt
# Get results: True
# Job jp_GvirlLt finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_GvirlLt/jp_GvirlLt.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_GvirlLt
# Your job status will be checked with the following parameters:
# Job id: jp_E5zqONV
# Get results: False
# Job jp_E5zqONV finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_E5zqONV/jp_E5zqONV.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_E5zqONV
# Get results: True
# Job jp_E5zqONV finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_E5zqONV/jp_E5zqONV.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_E5zqONV
# Your job status will be checked with the following parameters:
# Job id: jp_7nuTg14
# Get results: False
# Job jp_7nuTg14 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_7nuTg14/jp_7nuTg14.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_7nuTg14
# Get results: True
# Job jp_7nuTg14 finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_7nuTg14/jp_7nuTg14.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_7nuTg14
# Your job status will be checked with the following parameters:
# Job id: jp_G03Hpop
# Get results: False
# Job jp_G03Hpop finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_G03Hpop/jp_G03Hpop.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_G03Hpop
# Get results: True
# Job jp_G03Hpop finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_G03Hpop/jp_G03Hpop.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_G03Hpop
# Your job status will be checked with the following parameters:
# Job id: jp_5zcgY0x
# Get results: False
# Job jp_5zcgY0x finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_5zcgY0x/jp_5zcgY0x.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_5zcgY0x
# Get results: True
# Job jp_5zcgY0x finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_5zcgY0x/jp_5zcgY0x.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_5zcgY0x
# Your job status will be checked with the following parameters:
# Job id: jp_OS0f_0u
# Get results: False
# Job jp_OS0f_0u finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_OS0f_0u/jp_OS0f_0u.results.html
#
#
# Your job status will be checked with the following parameters:
# Job id: jp_OS0f_0u
# Get results: True
# Job jp_OS0f_0u finished. Results available at the following URL:
# http://www.compbio.dundee.ac.uk/jpred4/results/jp_OS0f_0u/jp_OS0f_0u.results.html
#
#
# Saving results to: /Users/xqua/Work/Extavour/Project/Oskar_Orthologs/Data/02_Oskar_analyses/jpred_tmp/jp_OS0f_0u

# %%
# Doing OSK
handle = SeqIO.parse(OSK_alignment_file, 'fasta')
seqs = [s for s in handle]
seqs = [clean_seq(seq) for seq in seqs]
seqs = [seq for seq in seqs if check_seq(seq)]
jobs = [submit_seq(seq, 'OSK_V3') for seq in seqs]
write_job_seq_table(jobs, 'OSK')
# Out:
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCPR01060865.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_jKHOJL2">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_jKHOJL2</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGLV01050081.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_nmBCZQD">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_nmBCZQD</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFCQ01023354.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_kH1itwC">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_kH1itwC</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g73831.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_1IMzXKq">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_1IMzXKq</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDYE01076282.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ft1Cual">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ft1Cual</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDYK01051721.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5eLeqnH">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5eLeqnH</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDZZ01021815.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wnE4N1w">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wnE4N1w</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDCJ01039934.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AE2FDnM">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AE2FDnM</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBCX01024638.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4BrJ9IK">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4BrJ9IK</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDPI01010195.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_RYLOWAq">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_RYLOWAq</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDPL01008940.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_LNkxvTh">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_LNkxvTh</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBHN01008234.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_PxwCvZb">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_PxwCvZb</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_023025754.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ztxtaVb">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ztxtaVb</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GEUF01006592.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_gPnMjPE">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_gPnMjPE</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGMU01005923.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_YSOmpfg">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_YSOmpfg</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGMU01146895.1_5.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_kPcZyB5">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_kPcZyB5</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDNW01019662.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_rkAlvKR">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_rkAlvKR</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDLA01009331.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_XgtRmZr">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_XgtRmZr</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGKQ01129231.1_6.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_G1NdWWR">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_G1NdWWR</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GEZY01023300.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_NIHlUda">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_NIHlUda</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6403.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_khqyOtZ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_khqyOtZ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAPE01019095.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3ZGITcC">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3ZGITcC</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_019880291.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Pe1l2KO">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Pe1l2KO</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g1846.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_KVY9tHP">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_KVY9tHP</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFGA01008784.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hNeWsHo">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hNeWsHo</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g1587.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_FC3oaWl">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_FC3oaWl</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GATI02024491.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AK4v1lH">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AK4v1lH</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCFF01018410.1_6.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bAQl2rZ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bAQl2rZ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_023301197.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_JT9clsk">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_JT9clsk</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAKJ01009501.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_xgF3jNy">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_xgF3jNy</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAKJ01010751.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_EFQM7A3">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_EFQM7A3</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBRL01010261.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Ypxldjn">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Ypxldjn</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGAW01019355.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BijfT_Y">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BijfT_Y</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAWM01006639.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Z_Y3kUO">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Z_Y3kUO</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGAN01008121.1_6.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3c2vpEC">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3c2vpEC</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGAN01011936.1_6.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_l_E5KOa">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_l_E5KOa</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGBJ01017529.1_5.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_F4Imsa9">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_F4Imsa9</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGBK01015896.1_6.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_uTUM8ay">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_uTUM8ay</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GANO01003814.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Cs8Obi6">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Cs8Obi6</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFNI01017354.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hzVoTv2">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hzVoTv2</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAZD02016917.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_yq1f563">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_yq1f563</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGBM01030935.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_zar6T8O">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_zar6T8O</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBTE01009320.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_EEkdiBd">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_EEkdiBd</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_001848641.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MEG6pHB">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MEG6pHB</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g2916.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_eMqzkcj">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_eMqzkcj</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g3426.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AmZW40x">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AmZW40x</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g3491.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_KD_Ipeq">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_KD_Ipeq</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g303.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hrh1uxJ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_hrh1uxJ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8324.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_FsX78po">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_FsX78po</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g5263.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_x3mbB5m">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_x3mbB5m</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8569.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_rWrpYYY">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_rWrpYYY</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6913.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_X1AumuM">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_X1AumuM</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8459.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_1jJVAjZ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_1jJVAjZ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g204.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_RAK_g2q">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_RAK_g2q</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8591.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fBmrKyw">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fBmrKyw</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g10533.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AHPwNtb">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AHPwNtb</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8282.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_YIJ7RWH">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_YIJ7RWH</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g2419.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sfMRnwG">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sfMRnwG</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g5007.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_d4EWHr_">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_d4EWHr_</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g2004.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_OP6geml">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_OP6geml</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g305.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_DJVlhJq">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_DJVlhJq</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGFL01000673.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_rc8F0rc">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_rc8F0rc</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_001656415.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_L1IjOqu">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_L1IjOqu</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFDL01015870.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Lp85hnv">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Lp85hnv</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_019540707.2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_YFoD8rx">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_YFoD8rx</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBEO01001325.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_C40GHi0">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_C40GHi0</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g10482.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_6ZNz1DA">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_6ZNz1DA</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_313289.3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_aoi04FA">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_aoi04FA</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GEMK01033802.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_SPlyJ3Z">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_SPlyJ3Z</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g4008.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_e19YoyZ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_e19YoyZ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCGO01032022.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BdcZHHX">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BdcZHHX</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GADM01000016.1_5.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bQPs2CX">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bQPs2CX</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_030572142.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_0osF5SV">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_0osF5SV</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_030374856.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_CKMCJo2">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_CKMCJo2</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_023173869.2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_QjzeX4b">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_QjzeX4b</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_001980894.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_794nkWn">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_794nkWn</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_022213619.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BlERs1U">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BlERs1U</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017856611.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5xMtIXQ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_5xMtIXQ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017071884.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ivyDeZ4">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ivyDeZ4</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_016978919.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_H8FuYWQ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_H8FuYWQ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017104763.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_VpCVJUP">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_VpCVJUP</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017014240.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__1OzeTZ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__1OzeTZ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017031605.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_D73vbOK">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_D73vbOK</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017123986.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_qGaJXNN">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_qGaJXNN</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_016961451.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_XSFLtMC">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_XSFLtMC</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017058667.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Mz5tIMp">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Mz5tIMp</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_017845653.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_JhvZAXx">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_JhvZAXx</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_002096875.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_448QqBN">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_448QqBN</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_002031969.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3cvR_Ca">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3cvR_Ca</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_001953297.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_lzprd_C">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_lzprd_C</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_001994345.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8gHOHid">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8gHOHid</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_002000116.2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_eZpfFxx">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_eZpfFxx</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_016941563.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_gOg51Q3">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_gOg51Q3</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_002070281.2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_iyLVhFm">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_iyLVhFm</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_002053269.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4kXkjVk">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4kXkjVk</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6282.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_UArYppy">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_UArYppy</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g9342.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_YpABN_0">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_YpABN_0</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g13566.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_m28LRvL">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_m28LRvL</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g14108.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_zHovDYI">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_zHovDYI</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g10514.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_dvLZ_QB">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_dvLZ_QB</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g9861.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_isVbXJe">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_isVbXJe</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6665.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_lMzkGL6">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_lMzkGL6</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g13723.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_g9DvJSS">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_g9DvJSS</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g4317.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_QgUwcMY">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_QgUwcMY</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g4469.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_J_6lLz6">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_J_6lLz6</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8280.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__sw2ODN">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__sw2ODN</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6827.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_XoKiOAF">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_XoKiOAF</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g10894.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wC0VVvl">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wC0VVvl</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g1452.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8KchwCw">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8KchwCw</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g2421.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8rrD4Mg">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8rrD4Mg</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g16848.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_gDdqx9A">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_gDdqx9A</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g7940.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_HDmUdhj">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_HDmUdhj</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g6005.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8x_P93a">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8x_P93a</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g12827.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8ubI0kM">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8ubI0kM</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8764.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_KqKhucq">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_KqKhucq</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g1694.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_PXqy5yg">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_PXqy5yg</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g10104.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_n3jVjw3">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_n3jVjw3</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g8692.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_v9t_O6H">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_v9t_O6H</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g510.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_7hq36SY">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_7hq36SY</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g757.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_7yovzKd">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_7yovzKd</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g989.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_KbRWjE_">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_KbRWjE_</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g1756.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_imwtjoB">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_imwtjoB</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g7457.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_PAgUo_4">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_PAgUo_4</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g2982.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_p3noB5w">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_p3noB5w</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g4964.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Wt74V_X">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_Wt74V_X</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# ...
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCVC01025397.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MdOOF6B">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_MdOOF6B</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_015178316.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8HAztc_">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_8HAztc_</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBOH01019111.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_mW1JxAO">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_mW1JxAO</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFS01087549.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_uE7AM3A">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_uE7AM3A</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFS01087545.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_o4UudF_">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_o4UudF_</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFS01087539.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tf69cKr">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_tf69cKr</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAFR01040300.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_eVdQ3qz">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_eVdQ3qz</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GBVH01018747.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AUhJrWB">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_AUhJrWB</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GATC02018205.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_0WbnuXo">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_0WbnuXo</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GATC02016035.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3sjqSMh">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3sjqSMh</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GENS01144527.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_2J6c4yM">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_2J6c4yM</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GENI01153520.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_yXOAKqp">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_yXOAKqp</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAYK02016970.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wbXFG8V">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wbXFG8V</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAUH02014402.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_LlW9NTj">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_LlW9NTj</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGKZ01013502.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_me1PO9G">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_me1PO9G</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GGFB01029731.1_5.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ep59sYP">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ep59sYP</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDVN01049780.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_OWisqm3">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_OWisqm3</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAWC01068728.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__HfWppZ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__HfWppZ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFVY01173144.1_5.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_msEgxj8">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_msEgxj8</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDBZ01020440.1_6.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_2JQn11R">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_2JQn11R</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDBZ01004059.1_5.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__ogFL1O">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp__ogFL1O</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAUF02003364.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_GtonH61">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_GtonH61</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCWY01017914.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wmIV2qd">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_wmIV2qd</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFK01042953.1_1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_iSCUX0M">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_iSCUX0M</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAYV02032680.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sWpN9jU">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sWpN9jU</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAYV02023556.1_6.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ZZyklPc">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_ZZyklPc</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFG01026980.1_5.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_VzB4b4i">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_VzB4b4i</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCZM01016483.1_6.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_z3qd4ax">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_z3qd4ax</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCXT01024844.1_6.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_2e8JXLg">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_2e8JXLg</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GDFM01026550.1_2.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4JnKKaj">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_4JnKKaj</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GCYQ01052767.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fnQ1Nht">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_fnQ1Nht</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAXG02090017.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_VpcBaiL">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_VpcBaiL</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAXC02020747.1_5.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BBHiv59">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_BBHiv59</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAYE02020013.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bEuLbjQ">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_bEuLbjQ</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/XP_026280917.1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_q1oQhDm">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_q1oQhDm</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g14948.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_eco_yw9">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_eco_yw9</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GFQQ01016007.1_6.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sJieDw2">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_sJieDw2</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAVM02025082.1_3.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_nyCmoPs">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_nyCmoPs</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GASS02003776.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3t8zO6v">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_3t8zO6v</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/g37762.t1.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_P9tHLWf">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_P9tHLWf</a></li></ul> Accepted
# Your job will be submitted with the following parameters:
# format: seq
# skipPDB: off
# file: ./tmp/GAYJ02042457.1_4.fasta
# email: lblondel@g.harvard.edu
# name: OSK_V3
# <h1>Created JPred job. Interactive access through:</h1><ul><li><a href="http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_pjQx9rj">http://www.compbio.dundee.ac.uk/jpred4/cgi-bin/chklog?jp_pjQx9rj</a></li></ul> Accepted

# %%
done = []
to_check = jobs
while len(done) != len(jobs):
    for job in jobs:
        jobid = job[1]
        if jobid not in done:
            status = jpredapi.status(jobid=jobid)
            if 'finished' in status.text:
                jpredapi.get_results(jobid=jobid, results_dir_path='../Data/02_Oskar_analyses/jpred_tmp/', extract=True)
                done.append(jobid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-63b4da9c8f2f> in <module>
#       1 done = []
# ----> 2 to_check = jobs
#       3 while len(done) != len(jobs):
#       4     for job in jobs:
#       5         jobid = job[1]
#
# NameError: name 'jobs' is not defined

# %% [markdown]
# ## Step 1: Create structure alignment and conf scores

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json, os, progressbar, requests, re, sys, time

from Bio.Seq import Seq
from Bio import AlignIO, SeqIO
from Bio.SeqRecord import SeqRecord
from Bio.Alphabet import generic_protein
from Bio.Align import MultipleSeqAlignment

import os 

data_path = '../Data/02_Oskar_analyses/'

# %matplotlib inline

# %%
def collect_scores(RES_PATH):
    results = {
        "OSK": {},
        "LOTUS": {}
    }
    jobs = pd.read_csv(os.path.join(RES_PATH, 'score.csv'))
    
    for jobid in [job for job in os.listdir(RES_PATH) if 'jp_' in job]:
        files = os.listdir(os.path.join(RES_PATH, jobid))
        domain = [file.split('_')[0] for file in files if ".name" in file][0]
        
        handle = SeqIO.parse(os.path.join(RES_PATH, jobid, jobid + '.seq'), 'fasta')
        seq = [s for s in handle][0]
        
        name = jobs[(jobs['domain'] == domain) & (jobs['job_id'] == jobid)]['seq_id'].values[0]
        
        f = open(os.path.join(RES_PATH, jobid, jobid + '.jnet'))
        for line in f.readlines():
            if "jnetpred:" in line:
                structure = ''.join([i for i in line.replace('jnetpred:','').strip('\n').split(',') if i])
            if "JNETCONF:" in line:
                score = ''.join([i for i in line.replace('JNETCONF:','').strip('\n').split(',') if i])
        
        results[domain][name] = { 
            "structure": structure,
            "score": score,
            "sequence": seq.seq
        }
        
    return results

# %%
results = collect_scores('../Data/02_Oskar_analyses/jpred_tmp/')

# %%
LOTUS_structures, LOTUS_scores = collect_scores(LOTUS_PATH)
OSK_structures, OSK_scores = collect_scores(OSK_PATH)

# %% [markdown]
# ## Step 2 : Save structure alignments and confidence scores from JPRED4 raw results

# %%
def save_structure_sequences(results, outputFile):
    my_sequences = []
    for key in results:
        seq = SeqRecord(Seq(results[key]['structure'], generic_protein), description='Jpred4 Structure Prediction', id=key)
        my_sequences.append(seq)
    SeqIO.write(my_sequences, outputFile, "fasta")

def save_jpred_scores(results, outputFile):
    output = open(outputFile,'w')
    for key in results:
        output.write(",".join([key] + list(results[key]['score'])) + '\n')
    output.close()

# %%
save_structure_sequences(results['LOTUS'], os.path.join(data_path, '2.6/STRUCTURES/LOTUS_raw_structures.faa'))
save_structure_sequences(results['OSK'], os.path.join(data_path, '2.6/STRUCTURES/OSK_raw_structures.faa'))
save_jpred_scores(results['LOTUS'], os.path.join(data_path, '2.6/LOTUS_jpred_scores.csv'))
save_jpred_scores(results['OSK'], os.path.join(data_path, '2.6/OSK_jpred_scores.csv'))

# %% [markdown]
# ## Step 3: Create structure alignment

# %%
def alignment_table(fastaFile):
    alignment = AlignIO.read(open(fastaFile), 'fasta')
    length = alignment.get_alignment_length()
    records = list(SeqIO.parse(fastaFile, 'fasta'))
    ID = [record.id.split('_')[0] for record in records]
    seq = [str(record.seq) for record in records]
    description = [record.description for record in records]
    description = [descr.split('|') for descr in description]
    description = [descr[len(descr)-1] for descr in description]
    seqInfos = [ID, description, seq]
    ALGN_DF = pd.DataFrame(data=seqInfos).T
    ALGN_DF.columns = ['ID', 'Description','Sequence']
    return ALGN_DF, length

def structure_table(structureFile):
    records = list(SeqIO.parse(structureFile, 'fasta'))
    ID = [ record.id.split('.')[0].split('_')[0] for record in records]
    seq = [str(record.seq) for record in records]
    strInfos = [ID, seq]
    STR_DF = pd.DataFrame(data=strInfos).T
    STR_DF.columns = ['ID','Sequence']
    return STR_DF

def get_position(alignment_mapping, ID, position):
    if position in alignment_mapping[ID]:
        return alignment_mapping[ID].index(position)

def save_structure_alignment(alignment_structure, outputFile):
    records = []
    for key in alignment_structure.keys():
        records.append(SeqRecord(Seq(alignment_structure[key], generic_protein), id=key))
    alignment = MultipleSeqAlignment(records)
    AlignIO.write(alignment, outputFile, 'fasta')
    
def build_score_table(jpredFile, ALGN_DF, length):
    jpred_scores = open(jpredFile)
    allLines = [line for line in jpred_scores.readlines()]
    conf_list = {}
    for line in allLines :
        line = line.strip('\n').split(',')
        name = line[0]
        conf = line[1:]
        conf_list[name] = conf
        
    scores_matrix = {}
    for ID in conf_list.keys() :
        if ID in ALGN_DF['ID'].values:
            name = ID
            List = []
            for i in range(length):
                indice = get_position(alignment_mapping, name,i)
                if  indice :
                    List.append(int(conf_list[ID][indice]))
                else :
                    List.append(float('Nan'))
            scores_matrix[name] = List
    DF = pd.DataFrame.from_dict(scores_matrix).T
    DF = DF.fillna(0)
    
    Scores = []
    Prediction = []
    for column in DF.columns:
        score = sum(DF[column])/len(DF.index)
        Scores.append(score)
    SCORES_DF = pd.DataFrame(Scores,columns=['JPRED_scores'])
    return SCORES_DF

# %%
LOTUS_structureFile = os.path.join(data_path, '2.6/STRUCTURES/LOTUS_raw_structures.faa')
ALGN_DF, length = alignment_table(LOTUS_alignement_file)
STR_DF = structure_table(LOTUS_structureFile)

### Identify aa index for each sequence in LOTUS alignment
alignment_mapping = {}
for index in ALGN_DF.index:
    name = ALGN_DF['ID'][index]
    List = []
    cpt = 0
    for i in ALGN_DF['Sequence'][index]:
        if i != '-':
            List.append(cpt)
        cpt += 1
    alignment_mapping[name] = List
    
### Create structure alignment based on indexed positions of the alignment
alignment_structure = {}
for index in STR_DF.index:
    print(STR_DF['ID'][index])
    if STR_DF['ID'][index] in ALGN_DF['ID'].values:
        name = str(STR_DF['ID'][index])
        print(name)
        List = []
        for i in range(length):
            indice = get_position(alignment_mapping, name, i)
            if  indice :
                List.append(STR_DF['Sequence'][index][indice].replace('-','X'))
            else :
                 List.append('-')
        alignment_structure[name] = ''.join(List)
        
LOTUS_jpredFile = os.path.join(data_path, '2.6/LOTUS_jpred_scores.csv')        
save_structure_alignment(alignment_structure, os.path.join(data_path, '2.6/STRUCTURES/LOTUS_structures_alignment.fasta'))
LOTUS_JPRED_SCORES = build_score_table(LOTUS_jpredFile, ALGN_DF, length)
# Out:
# GBUQ01011587
# g8282
# g2989
# GAYK02016970
# GAYV02023556
# GDJM01009268
# GGAV01025392
# g19924
# GBVR01016885
# GFGA01008784
# XP
# XP
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-c4056e268819> in <module>
#      26             indice = get_position(alignment_mapping, name, i)
#      27             if  indice :
# ---> 28                 List.append(STR_DF['Sequence'][index][indice].replace('-','X'))
#      29             else :
#      30                  List.append('-')
#
# IndexError: string index out of range

# %%
OSK_fastaFile = '../Data/Oskar_sequences/OSK_consensus_alignment.fasta'
OSK_structureFile = os.path.join(data_path, '2.6/STRUCTURES/OSK_raw_structures.faa')
ALGN_DF, length = alignment_table(OSK_fastaFile)
STR_DF = structure_table(OSK_structureFile)

### Identify aa index for each sequence in LOTUS alignment
alignment_mapping = {}
for index in ALGN_DF.index:
    name = ALGN_DF['ID'][index]
    List = []
    cpt = 0
    for i in ALGN_DF['Sequence'][index]:
        if i != '-':
            List.append(cpt)
        cpt += 1
    alignment_mapping[name] = List
    
## Create structure alignment based on indexed positions of the alignment
alignment_structure = {}
for index in STR_DF.index:
    if STR_DF['ID'][index] in ALGN_DF['ID'].values:
        name = str(STR_DF['ID'][index])
        List = []
        for i in range(length):
            indice = get_position(alignment_mapping, name,i)
            if  indice :
                List.append(STR_DF['Sequence'][index][indice].replace('-','X'))
            else :
                 List.append('-')
        alignment_structure[name] = ''.join(List)
        

OSK_jpredFile = os.path.join(data_path, '2.6/OSK_jpred_scores.csv')
save_structure_alignment(alignment_structure, os.path.join(data_path, '2.6/STRUCTURES/OSK_structures_alignment.fasta'))
OSK_JPRED_SCORES = build_score_table(OSK_jpredFile, ALGN_DF, length)

# %% [markdown]
# #### Structure confidence score for LOTUS

# %%
fig = plt.figure(figsize=(50,10))
g = sns.barplot(y='JPRED_scores', x=LOTUS_JPRED_SCORES.index, data=LOTUS_JPRED_SCORES, color='#ff4c4c')
for item in g.get_xticklabels():
    item.set_rotation(90)
    
plt.ylabel('Jpred confidence score')
plt.xlabel('position')
plt.title('Confidence score for secondary structure analysis of LOTUS domain')
plt.show()

# %% [markdown]
# #### Structure confidence score for OSK

# %%
fig = plt.figure(figsize=(50,10))
g = sns.barplot(y='JPRED_scores', x=OSK_JPRED_SCORES.index, data=OSK_JPRED_SCORES, color='#ff4c4c')
for item in g.get_xticklabels():
    item.set_rotation(90)
    
plt.ylabel('Jpred confidence score')
plt.xlabel('position')
plt.title('Confidence score for secondary structure analysis of OSK domain')
plt.show()

# %% [markdown]
# ## Step 5: Create specifc alignments for different LOTUS conformation

# %% [markdown]
# Cited paper

# %%
LOTUS_conformation = {
    'Drosophilidae':'dimerization',
    'Tethrilidae':'dimerization',
    'Pteromalidae':'dimerization',
    'Culicidae':'monomerization',
    'Formicidae':'monomerization',
    'Grillidae':'monomerization'
}

def set_lotus_form(x):
    if x in LOTUS_conformation :
        return LOTUS_conformation[x]

# %%
def oskar_lotus_conformation(JSON_FILE):
    with open(JSON_FILE, encoding='utf-8') as data_file:
        alldata_infos = json.loads(data_file.read())

    tmp = []
    already = []
    for Id in alldata_infos :
        species = alldata_infos[Id]['ID']
        order = alldata_infos[Id]['metadata']['order']['name']
        family = alldata_infos[Id]['metadata']['family']['name']
        if 'Transcriptome_analysis' in alldata_infos[Id] :
            for analysis in alldata_infos[Id]['Transcriptome_analysis']:
                if len(analysis['result']['oskar']['validated']) != 0 :
                    for seq in analysis['result']['oskar']['validated'] :
                        if seq not in already :
                            already.append(seq)
                            if set_lotus_form(family) == 'dimerization' :
                                tmp.append([seq,species,order,family,'dimerization'])
                            elif set_lotus_form(family) == 'monomerization' :
                                tmp.append([seq,species,order,family,'monomerization'])
                            else :
                                tmp.append([seq,species,order,family,'na'])

    if 'Genome_analysis' in alldata_infos[Id] :
        for analysis in alldata_infos[Id]['Genome_analysis']:
            if len(analysis['result']['oskar']['validated']) != 0 :
                for seq in analysis['result']['oskar']['validated'] :
                    if seq not in already :
                        already.append(seq)
                        if set_lotus_form(family) == 'dimerization' :
                            tmp.append([seq,species,order,family,'dimerization'])
                        elif set_lotus_form(family) == 'monomerization' :
                            tmp.append([seq,species,order,family,'monomerization'])
                        else :
                            tmp.append([seq,species,order,family,'na'])


    LOTUS_DF = pd.DataFrame(tmp, columns=['id','species','order','family','conformation'])
    return LOTUS_DF

# %%
JSON_FILE = '../Data/JSON_oskar_analysis.json'
LOTUS_DF = oskar_lotus_conformation(JSON_FILE)

# %% [markdown]
# #### Sub table for LOTUS dimers and monomers

# %%
dimerization_df = LOTUS_DF[LOTUS_DF['conformation'] == 'dimerization']
monomerization_df = LOTUS_DF[LOTUS_DF['conformation'] == 'monomerization']

# %%
def save_specific_structure_alignment(lotus_conformation_df, structureFile, outFile):
    my_lotus_records = []
    for seq in lotus_conformation_df['id'].values :
        for seq_record in SeqIO.parse(structureFile, 'fasta'):
            if seq == seq_record.id :
                tmp = SeqRecord( Seq(str(seq_record.seq), generic_protein), id=seq_record.id, name=seq_record.id, description=seq_record.description)
                my_lotus_records.append(tmp)
        SeqIO.write(my_lotus_records, outFile, "fasta")
        
def save_oskar_lotus_conformation_alignment(lotus_conformation_df, fastaFile, outFile):
    my_records = []
    for seq in lotus_conformation_df['id'].values :
        for seq_record in SeqIO.parse(fastaFile, 'fasta'):
            if seq == seq_record.id :
                tmp = SeqRecord( Seq(str(seq_record.seq), generic_protein), id=seq_record.id, name=seq_record.id, description=seq_record.description)
                my_records.append(tmp)
    SeqIO.write(my_records, outFile, "fasta")

# %%
LOTUS_STR_ALIGNMENT = os.path.join(data_path, '2.6/STRUCTURES/LOTUS_structures_alignment.fasta')
OSKAR_FASTA_FILE = '../Data/Oskar_sequences/OSKAR_consensus_alignment.fasta'
save_specific_structure_alignment(dimerization_df, LOTUS_STR_ALIGNMENT, os.path.join(data_path, '2.6/STRUCTURES/LOTUS_dimerization_structures_alignment.fasta'))
save_specific_structure_alignment(monomerization_df, LOTUS_STR_ALIGNMENT, os.path.join(data_path, '2.6/STRUCTURES/LOTUS_mononomerization_structures_alignment.fasta'))
save_oskar_lotus_conformation_alignment(dimerization_df, OSKAR_FASTA_FILE, os.path.join(data_path, '2.6/FASTA/OSKAR_dimerization.fasta'))
save_oskar_lotus_conformation_alignment(dimerization_df, OSKAR_FASTA_FILE, os.path.join(data_path, '2.6/FASTA/OSKAR_monomerization.fasta'))
